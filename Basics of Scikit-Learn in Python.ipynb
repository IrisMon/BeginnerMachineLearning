# %% [markdown]
# <a href="https://colab.research.google.com/github/IrisMon/BeginnerMachineLearning/blob/main/Basics%20of%20Scikit-Learn%20in%20Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Basic of Scikit Learn**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
##Import the scikit - learn library
import sklearn

# %%
##!pip install scikit-learn==0.22.1

# %%
#Check the version, we need 0.22.1
sklearn.__version__
# Out:
# '0.22.2.post1'

# %% [markdown]
# * We have seen in the pandas notebook , that we have some missing values in out data.
# * We will impute those missing values using the scikit-learn Imputer.

# %%
import pandas as pd
data=pd.read_csv('/content/big_mart_sales.csv')
data.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
#import the SimpleImputer
from sklearn.impute import SimpleImputer

# %% [markdown]
# * For imputing the missing values, we will use SimpleImputer.
# * First we will create an object of the Imputer and define the strategy.
# * We will impute the Item_eight by mean value and Outle_Size by most_fequent value
# *  Fit the objects with the data
# * Transform the data

# %%
# Create the object of the imputer for IemWeight and Outlet_Size
impute_weight=SimpleImputer(strategy='mean')
impute_size= SimpleImputer(strategy='most_frequent')

# %%
#Fit the Iten_Weight imputer with the data and transform
impute_weight.fit(data[['Item_Weight']])
data.Item_Weight=impute_weight.transform(data[['Item_Weight']])

# %%
#Fit the Outlet_Size imputer with the data and transform
impute_size.fit(data[['Outlet_Size']])
data.Outlet_Size=impute_size.transform(data[['Outlet_Size']])

# %%
#Chech the null values
data.isna().sum()
# Out:
# Item_Identifier              0
# Item_Weight                  0
# Item_Fat_Content             0
# Item_Visibility              0
# Item_Type                    0
# Item_MRP                     0
# Outlet_Identifier            0
# Outlet_Establishment_Year    0
# Outlet_Size                  0
# Outlet_Location_Type         0
# Outlet_Type                  0
# Item_Outlet_Sales            0
# dtype: int64

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# some of the very basic models scikit learn has 
from sklearn.linear_model import LinearRegression 
from sklearn.tree import DecisionTreeClassifier

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from sklearn.pipeline import Pipeline

# %% [markdown]
# We will study each of the step in detail in the upcoming modules
