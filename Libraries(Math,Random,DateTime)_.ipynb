# %% [markdown]
# <a href="https://colab.research.google.com/github/IrisMon/BeginnerMachineLearning/blob/main/Libraries(Math%2CRandom%2CDateTime)_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Python Standard Library**

# %%
#MATH
import math

# %%
## The smallest integer greater than or equal X.
math.ceil(22.2356)
# Out:
# 23

# %%
# the largest integer less than or equal to X
math.floor(20.33)
# Out:
# 20

# %%
#factorial of a number
math.factorial(20)
# Out:
# 2432902008176640000

# %%
## Greatest common divisor of the integers a and b
math.gcd(100,200)
# Out:
# 100

# %%
## More details: https://docs.python.org/3/library/math.html

# %%
import random

# %%
## Select a random element from a list
random.choice(['Gato','Perro','Oveja'])
# Out:
# 'Perro'

# %%
### Select 10 diffent numbers within a range of numbers
random.sample(range(1,100),10)
# Out:
# [54, 99, 29, 8, 21, 30, 74, 3, 73, 42]

# %%
#Select a random float number 
random.random()
# Out:
# 0.7454203947491642

# %%
#Selecr a random float number witrhin a range
random.uniform(0,0.2)
# Out:
# 0.03815459493476647

# %%
## Randon intger chosen fron range(6)
random.randrange(3,6)
# Out:
# 3

# %%
random.randint(1,20)
# Out:
# 17

# %% [markdown]
# DATE TIME
#
# ![image.png](data:image/png;base64,...)

# %%
#Dates are easily construed and formatted
from datetime import date

# %%
TODAY=date.today()
print('Date: ', TODAY)
# Out:
# Date:  2021-01-10

# %%
#Format date 
print('Formatted date:', TODAY.strftime("%m-%d-%y."))
# Out:
# Formatted date: 01-10-21.

# %%
#Format Date
print('Formatted date:', TODAY.strftime("%d-%b-%Y."))
# Out:
# Formatted date: 10-Jan-2021.

# %%
print('Formatted date:', TODAY.strftime("%m-%d-%Y."))
# Out:
# Formatted date: 01-10-2021.

# %%
#Format date
print('Formatted date.',TODAY.strftime("%A on the %d day of %B"))
# Out:
# Formatted date. Sunday on the 10 day of January

# %%
#Dates support calendar arithmetic
birthday= date(1994,8,22)
age=TODAY-birthday
print('Age in days',age.days/365)
# Out:
# Age in days 26.405479452054795

# %% [markdown]
# OS - OPERATING SYSTEM
#
# *  The os module provides dozens of functions for interacting with the operating system

# %%
import os
print('Get current working directory', os.getcwd())
# Out:
# Get current working directory /content

# %%
## List contents of a directory
print('Listing ecisting directories')
os.listdir()
# Out:
# Listing ecisting directories
# ['.config', 'sample_data']

# %%
# Run the command mkdir in the system shell
print('make new directory')
os.system('mkdir Today')
# Out:
# make new directory
# 0
